# %% [markdown]
# Project Module #5: CPSMA-3913-01
# Dr Matthew Lynam

# %% [markdown]
# ![Study-Pics-250kb-2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Create a Tree Structure to Show My Daily Study method I'll be drawing a tree structure to represent my daily study this project. The structure will have nodes for the many things I do during my study and edges for the sequence in which I perform those things.

# %%
# !pip install anytree

from anytree import Node, RenderTree
from anytree.exporter import DotExporter
from IPython.display import display, Image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 1.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Next, I'll create the nodes for my daily study cycle, starting with the root node, which represents preview.

# %%
preview = Node("Preview")

# %% [markdown]
# Then I will add nodes for attending class.

# %%
attend= Node("Attend")

# %% [markdown]
# Then I will add nodes for review and study.

# %%
review= "Review"
study="Study"

# %% [markdown]
# Then I will add nodes for Asses that am I using the study methods that are effective

# %%
assess= "assess"

# %% [markdown]
# ![Screen Shot 2023-02-13 at 2.40.07 AM.png](data:image/png;base64,...)

# %% [markdown]
# This structure provides me with an overview of my Study as well as a visual representation of the sequence in which I execute my daily study. Each of the child nodes reflects the things I do after to learn.

# %% [markdown]
# **(b) Visualize your structure using graphviz package.**

# %% [markdown]
# Its very simple step by step going forward process which starts with preview then attend, review, study and end with assess

# %% [markdown]
# **(c) Describe a path in your structure.**

# %% [markdown]
# Its One path in my structure.

# %% [markdown]
# **(d) Describe the degree of a vertex.**

# %% [markdown]
# Its a 5 degree vertex here I got 5 edges

# %% [markdown]
# **(e) Describe a cycle in your structure if it exists. If a cycle does not exist, explain how you know.**

# %% [markdown]
# In my graph there is no cycle exist because it starts with preview and ends with assess. There is no coming back to starting edges or there is no closed chain.
